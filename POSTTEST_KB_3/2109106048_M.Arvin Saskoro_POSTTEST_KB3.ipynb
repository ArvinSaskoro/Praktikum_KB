# %% [markdown]
# Nama  : M. Arvin Saskoro
# NIM   : 2109106048
# Kelas : A2 21
#
# Dataset : drug deaths

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# SEABORN

# %%
sns.set_style("ticks")
plt.figure(figsize = (10,7))
sns.countplot(data = df, y = "Heroin", hue = "Cocaine", color = "aqua")
# Out:
# <AxesSubplot: xlabel='count', ylabel='Heroin'>

# %% [markdown]
# SCATTER PLOT

# %%
df = pd.read_csv('drug_deaths.csv')
df.head()

sns.scatterplot(data = df, x = "Age", y = "Location")
plt.title("Tingkat Kematian di Suatu Tempat Berdasarkan Umur")
plt.show()

# %% [markdown]
# PIE PLOT

# %%
data_pie = df['Location'].value_counts().rename('Location').reset_index(name = 'id_count')
plt.pie(data_pie.id_count, labels = data_pie['index'], startangle = 180, autopct = '%.1f%%',
        shadow = True)
plt.title('Tingkat Kematian Terhadap Overdosis Obat-obatan di Suatu Tempat')
plt.show()
